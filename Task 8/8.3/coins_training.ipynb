# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.0/617.0 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/drive/MyDrive/M.I.ACoins/coins.zip
# Out:
# Archive:  /content/drive/MyDrive/M.I.ACoins/coins.zip
#    creating: coins/train/
#    creating: coins/train/images/
#   inflating: coins/train/images/pound01.jpg
#   inflating: coins/train/images/pound02.jpg
#   inflating: coins/train/images/pound03.jpg
#   inflating: coins/train/images/pound04.jpg
#   inflating: coins/train/images/pound05.jpg
#   inflating: coins/train/images/pound06.jpg
#   inflating: coins/train/images/pound07.jpg
#   inflating: coins/train/images/pound08.jpg
#   inflating: coins/train/images/pound09.jpg
#   inflating: coins/train/images/pound10.jpg
#   inflating: coins/train/images/pound11.jpg
#   inflating: coins/train/images/pound12.jpg
#   inflating: coins/train/images/pound13.jpg
#   inflating: coins/train/images/pound14.jpg
#   inflating: coins/train/images/pound15.jpg
#   inflating: coins/train/images/pound16.jpg
#   inflating: coins/train/images/pound17.jpg
#   inflating: coins/train/images/pound18.jpg
#   inflating: coins/train/images/pound19.jpg
# ...

# %%
# %cd /content/drive/MyDrive/M.I.ACoins
# Out:
# /content/drive/MyDrive/M.I.ACoins

# %%
# !yolo task=detect mode=train data=/content/coins.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 73.9MB/s]
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
